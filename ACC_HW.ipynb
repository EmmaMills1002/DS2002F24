# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmaMills1002/DS2002F24/blob/main/ACC_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
acc = pd.read_csv('/content/acc_players-2324F.csv', header=1)
acc.head()
# Out:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %% [markdown]
# **Basic Analysis**

# %%
acc['PTS'].sum()
# Out:
# 38411

# %%
most_minutes = acc[['Player', 'MP']].sort_values(by='MP', ascending=False).head(1)
print(most_minutes)
# Out:
#             Player    MP
# 135  Casey Morsell  1333

# %%
top_rebounds = acc[['Player', 'TRB']].sort_values(by='TRB', ascending=False).head(5)
print(top_rebounds)
# Out:
#               Player  TRB
# 5      Armando Bacot  380
# 178  Ian Schieffelin  340
# 90   Harrison Ingram  327
# 44    Mohamed Diarra  311
# 149    Norchad Omier  309

# %% [markdown]
# **Player Filtering**

# %%
most_mp = acc[acc['MP']>500]

# %%
most_mp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 2 to 215
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rk      98 non-null     int64
#  1   Player  98 non-null     object
#  2   Class   98 non-null     object
#  3   Pos     98 non-null     object
#  4   School  98 non-null     object
#  5   G       98 non-null     int64
#  6   MP      98 non-null     int64
#  7   TRB     98 non-null     int64
#  8   AST     98 non-null     int64
#  9   STL     98 non-null     int64
#  10  BLK     98 non-null     int64
#  11  TOV     98 non-null     int64
#  12  PF      98 non-null     int64
#  13  PTS     98 non-null     int64
#  14  FG%     98 non-null     float64
#  15  2P%     98 non-null     float64
#  16  3P%     95 non-null     float64
#  17  FT%     98 non-null     float64
#  18  PER     98 non-null     float64
#  19  WS      98 non-null     float64
#  20  BPM     98 non-null     float64
# ...

# %%
top_assists = acc[['Player', 'AST']].sort_values(by='AST', ascending=False).head(1)
print(top_assists)
# Out:
#           Player  AST
# 7  Reece Beekman  212

# %%
top_three_assists = acc[['Player', 'AST']].sort_values(by='AST', ascending=False).head(3)
print(top_three_assists)
# Out:
#              Player  AST
# 7     Reece Beekman  212
# 215  Jaeden Zackery  152
# 21    Elliot Cadeau  150

# %%
top_shotblockers = acc[['Player', 'STL']].sort_values(by='STL', ascending=False).head(3)
print(top_shotblockers)
# Out:
#             Player  STL
# 16     Maliq Brown   71
# 7    Reece Beekman   68
# 132    Judah Mintz   67

# %% [markdown]
# **School-Based Analysis**

# %%
school_points = acc.groupby('School')[['PTS']].sum().sort_values('PTS', ascending=False)
school_points
# Out:
#                  PTS
# School
# NC State        3101
# North Carolina  3032
# Duke            2830
# Clemson         2785
# Wake Forest     2733
# Boston College  2667
# Virginia Tech   2547
# Florida State   2526
# Pittsburgh      2495
# Syracuse        2442
# Miami (FL)      2424
# Louisville      2304
# Georgia Tech    2272
# Virginia        2140
# Notre Dame      2113

# %%
acc.groupby('School')[['AST']].sum().sort_values('AST', ascending=False)
# Out:
#                 AST
# School
# Duke            551
# NC State        536
# North Carolina  536
# Clemson         533
# Virginia Tech   514
# Boston College  509
# Virginia        509
# Miami (FL)      454
# Pittsburgh      452
# Syracuse        442
# Wake Forest     429
# Georgia Tech    425
# Florida State   406
# Louisville      356
# Notre Dame      335

# %%
school_points.head(3)
# Out:
#                  PTS
# School
# NC State        3101
# North Carolina  3032
# Duke            2830
